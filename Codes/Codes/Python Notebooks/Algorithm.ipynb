# %%
# %run /MovielensDatasetAnalysis/Authorization
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: </div>
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=2830107696680983#setting/sparkui/1110-070702-3ptlkajl/driver-9186042205165632912">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://10.139.64.4:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>
# <style scoped>
# ...

# %%
#import required libraries
import datetime
import pyspark.sql.functions as f
import pyspark.sql.types
import pandas as pd

from pyspark.sql.functions import year, month, dayofmonth
from pyspark.sql.functions import unix_timestamp, from_unixtime
from pyspark.sql import Window
from pyspark.sql.functions import rank, min
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#test check to access the container
dbutils.fs.ls("abfss://containerdatalake@samovielensanalysis.dfs.core.windows.net")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: [FileInfo(path=&#39;abfss://containerdatalake@samovielensanalysis.dfs.core.windows.net/ml-latest-small.zip&#39;, name=&#39;ml-latest-small.zip&#39;, size=978202)]</div>

# %%
#List all the  Mounts
dbutils.fs.mounts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: [MountInfo(mountPoint=&#39;/databricks-datasets&#39;, source=&#39;databricks-datasets&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/databricks/mlflow-tracking&#39;, source=&#39;databricks/mlflow-tracking&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/movielens&#39;, source=&#39;wasbs://containerdatalake@samovielensanalysis.blob.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/databricks-results&#39;, source=&#39;databricks-results&#39;, encryptionType=&#39;&#39;),
# ...

# %%
#Unzip the file Using the DBFS
dbutils.fs.cp("dbfs:/mnt/movielens/ml-latest-small.zip", "file:/tmp/ml-latest-small.zip")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: True</div>

# %%
# %sh
ls -l /tmp/ml-latest-small.zip
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">-rw-r--r-- 1 root root 978202 Nov 10 18:30 /tmp/ml-latest-small.zip
# </div>

# %%
# %sh
rm -r /tmp/ml-latest-small.zip/

# %%
# %sh
unzip /tmp/ml-latest-small.zip -d /tmp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Archive:  /tmp/ml-latest-small.zip
#    creating: /tmp/ml-latest-small/
#   inflating: /tmp/ml-latest-small/links.csv
#   inflating: /tmp/ml-latest-small/tags.csv
#   inflating: /tmp/ml-latest-small/ratings.csv
#   inflating: /tmp/ml-latest-small/README.txt
#   inflating: /tmp/ml-latest-small/movies.csv
# </div>

# %%
dbutils.fs.ls("file:/tmp/ml-latest-small/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: [FileInfo(path=&#39;file:/tmp/ml-latest-small/ratings.csv&#39;, name=&#39;ratings.csv&#39;, size=2483723),
#  FileInfo(path=&#39;file:/tmp/ml-latest-small/links.csv&#39;, name=&#39;links.csv&#39;, size=197979),
#  FileInfo(path=&#39;file:/tmp/ml-latest-small/README.txt&#39;, name=&#39;README.txt&#39;, size=8342),
#  FileInfo(path=&#39;file:/tmp/ml-latest-small/tags.csv&#39;, name=&#39;tags.csv&#39;, size=118660),
#  FileInfo(path=&#39;file:/tmp/ml-latest-small/movies.csv&#39;, name=&#39;movies.csv&#39;, size=494431)]</div>

# %%
#dbutils.fs.ls("file:/databricks/driver/filename")

# %%
#dbutils.fs.unmount("/mnt/<mountpoint>")

# %%
dbutils.fs.cp("file:/tmp/ml-latest-small/movies.csv", "abfss://containerdatalake@samovielensanalysis.dfs.core.windows.net/movies.csv") 
dbutils.fs.cp("file:/tmp/ml-latest-small/ratings.csv", "abfss://containerdatalake@samovielensanalysis.dfs.core.windows.net/ratings.csv") 
dbutils.fs.cp("file:/tmp/ml-latest-small/tags.csv", "abfss://containerdatalake@samovielensanalysis.dfs.core.windows.net/tags.csv") 
dbutils.fs.cp("file:/tmp/ml-latest-small/links.csv", "abfss://containerdatalake@samovielensanalysis.dfs.core.windows.net/links.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: True</div>

# %%
# %fs ls abfss://containerdatalake@samovielensanalysis.dfs.core.windows.net/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls abfss://containerdatalake@samovielensanalysis.dfs.core.windows.net/Source/ml-latest-small.zip/ml-latest-small/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls /FileStore/tables/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/links.csv</td><td>links.csv</td><td>197979</td></tr><tr><td>dbfs:/FileStore/tables/movies.csv</td><td>movies.csv</td><td>494431</td></tr><tr><td>dbfs:/FileStore/tables/ratings.csv</td><td>ratings.csv</td><td>2483723</td></tr><tr><td>dbfs:/FileStore/tables/tags.csv</td><td>tags.csv</td><td>118660</td></tr></tbody></table></div>

# %%
# File location and type
file_location = "/mnt/movielens/movies.csv"

file_type = "csv"



# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
 
df_movies = spark.read.format(file_type) \
      .option("inferSchema", infer_schema) \
      .option("header", first_row_is_header) \
      .option("sep", delimiter) \
      .load(file_location)
    
display(df_movies)
df_movies.count()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#Read data "link"
links="/mnt/movielens/links.csv"
df_links = spark.read.format(file_type) \
      .option("inferSchema", infer_schema) \
      .option("header", first_row_is_header) \
      .option("sep", delimiter) \
      .load(links)
    
display(df_links)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#Read data "tags"
tags="/mnt/movielens/tags.csv"
df_tags = spark.read.format(file_type) \
      .option("inferSchema", infer_schema) \
      .option("header", first_row_is_header) \
      .option("sep", delimiter) \
      .load(tags)
    
display(df_tags)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#Read data "ratings"
ratings="/mnt/movielens/ratings.csv"
df_ratings = spark.read.format(file_type) \
      .option("inferSchema", infer_schema) \
      .option("header", first_row_is_header) \
      .option("sep", delimiter) \
      .load(ratings)
    
display(df_ratings)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#count of records
df_movies.count()

# %%
display(df_movies)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#first join movies and ratings tables
df_movies_with_ratings = df_movies.join(df_ratings,'movieId','left')

display(df_movies_with_ratings)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#Check if there are no duplicates
df_movies_no_dups = df_movies_with_ratings.groupby('movieId').count()
display(df_movies_no_dups)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_movies.where(df_movies.movieId.isin([296,593, 858])).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th><th>genres</th></tr></thead><tbody><tr><td>296</td><td>Pulp Fiction (1994)</td><td>Comedy|Crime|Drama|Thriller</td></tr><tr><td>593</td><td>Silence of the Lambs, The (1991)</td><td>Crime|Horror|Thriller</td></tr><tr><td>858</td><td>Godfather, The (1972)</td><td>Crime|Drama</td></tr></tbody></table></div>

# %%
#Join with users dataset
df_movies_with_ratings=df_movies_with_ratings.join(df_tags,['movieID','userId'],'inner')
display(df_movies_with_ratings)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#Join with ratings with tag
df_ratings_tags=df_ratings.join(df_tags,['movieID'],'inner')
display(df_movies_with_ratings)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_ratings_add_tsdate=df_ratings.withColumn("tsdate",f.from_unixtime("timestamp"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_ratings_add_tsdate.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_selected_rating_date=df_ratings_add_tsdate.select('userid','movieid','rating',f.to_date(unix_timestamp('tsdate','yyyy-MM-dd HH:mm:ss').cast('timestamp')).alias('rating_date'))
df_selected_rating_date.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_rating_year=df_selected_rating_date.groupBy('rating_date').count()
df_rating_year.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_avg_ratings=df_selected_rating_date.groupBy('movieid').mean('rating')
df_avg_ratings.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df=df_avg_ratings.join(df_movies,'movieid', 'inner')
df=df.withColumnRenamed('avg(rating)', 'avg_rating')
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_total_rating=df_selected_rating_date.groupBy('movieid').count()
df_total_rating.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_total_rating=df_total_rating.filter(df_total_rating['count']>50)
df_ratings_filtered=df_selected_rating_date.join(df_total_rating, 'movieid', 'inner')
df_ratings_filtered.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_total_rating.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[62]: 436</div>

# %%
df_rating_per_user=df_ratings_filtered.select('userid','movieid','rating').groupBy('userid', 'movieid').max('rating')
df_rating_per_user_movie=df_rating_per_user.join(df_movies,'movieid','inner')
df_rating_per_user_movie=df_rating_per_user_movie.withColumnRenamed('max(rating)', 'max_rating')
df_rating_per_user_movie.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_rating_max_rating=df_rating_per_user_movie.groupBy('userid','movieid','title','genres').max('max_rating')
df_rating_max_rating=df_rating_max_rating.withColumnRenamed('max(max_rating)', 'max_rating')
df_rating_max_rating.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_rating_max_rating=df_rating_max_rating.filter(df_rating_max_rating['max_rating']>=4)
df_rating_max_rating.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#identify best movies per genre
df_movies_per_genere=df_rating_max_rating.groupBy('genres','title').count()
df_movies_per_genere.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#identify genres of user
df_ratings_genre=df_rating_max_rating.select('userid','title','genres').groupBy('userid','genres').count()
df_ratings_genre.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#latest Trending Movies Over all
df_recent_movie=df_ratings_filtered.groupBy('userid','movieid').agg(f.max(df_ratings_filtered['rating_date']))
df_recent_movie.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_movies_per_genere=df.groupBy('genres').avg('avg_rating')
display(df_movies_per_genere)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Create a view or table

temp_table_name = "movies_csv"

df_movies.createOrReplaceTempView(temp_table_name)

# %%
# %sql

/* Query the created temp table in a SQL cell */

select * from `movies_csv`

# %%
# %sql
DROP TABLE IF EXISTS default.permanent_table_name;

# %%
# With this registered as a temp view, it will only be available to this particular notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
# To do so, choose your table name and uncomment the bottom line.

permanent_table_name = "permanent_table_name"

df_movies.write.format("parquet").saveAsTable(permanent_table_name)

# %%
# %sql

/* Query the created temp table in a SQL cell */

select * from `permanent_table_name`
