# %%
spark
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: </div>
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=2830107696680983#setting/sparkui/1110-070702-3ptlkajl/driver-9186042205165632912">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://10.139.64.4:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# Connect to Azure Data Lake Storage
spark.conf.set(
    "fs.azure.account.key.samovielensanalysis.dfs.core.windows.net",
    "T25IhRW0Gf7nsJGr4l6TVYz903afyhxPy/8kmaiy9DNDSB4Oy/yJSMtl9ezzXcyas4IgXjCqBFHDkSBpIYhdIw==")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Access the files in the container
dbutils.fs.ls("abfss://containerdatalake@samovielensanalysis.dfs.core.windows.net/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: [FileInfo(path=&#39;abfss://containerdatalake@samovielensanalysis.dfs.core.windows.net/ml-latest-small.zip&#39;, name=&#39;ml-latest-small.zip&#39;, size=978202)]</div>

# %%
#Create Mount Point on DBFS 
#dbutils.fs.mount(
#  source = "wasbs://containerdatalake@samovielensanalysis.blob.core.windows.net",
#  mount_point = "/mnt/movielens",
#  extra_configs = {"fs.azure.sas.containerdatalake.samovielensanalysis.blob.core.windows.net":"sp=r&st=2021-11-10T18:10:03Z&se=2021-11-11T02:10:03Z&spr=https&sv=2020-08-04&sr=c&sig=GpQ4eLr2XMr3UgHmDS3AdMB%2F6I5WvC2y5r3QVE4M1Dk%3D"})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: True</div>

# %%
dbutils.fs.ls("/mnt/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: [FileInfo(path=&#39;dbfs:/mnt/movielens/&#39;, name=&#39;movielens/&#39;, size=0)]</div>

# %%
#Unmount a mount point
#dbutils.fs.unmount("/mnt/<mount-point-name>")
